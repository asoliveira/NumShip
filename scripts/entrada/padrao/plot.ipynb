# %%
import matplotlib.pyplot as pltimport scipy as sp

# %%
x = sp.genfromtxt('CurvaGiro/pos.dat')

# %%
a = plt.plot(x[:,2], x[:,1])plt.grid(True, 'both', color = 'g', linestyle = '--', linewidth = 1, markersize = 5)plt.show(a)

# %%
plt.grid?
